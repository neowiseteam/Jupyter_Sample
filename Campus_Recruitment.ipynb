# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

import pandas as pd 
data
# Out:
# {'apples': [3, 2, 0, 1], 'oranges': [0, 3, 7, 2]}

# %%
df = pd.read_csv('csvfiles/data.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-85486c239ff7> in <module>
# ----> 1 df = pd.read_csv('csvfiles/data.csv')
#       2 df
#
# /opt/conda/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
df = pd.read_csv('csv/test.csv')
df
# Out:
#     Student_ID  Aptitude_Score  Techincal_Score  Projects  Resume_Strength  \
# 0          401             304              100         2              3.5
# 1          402             315              105         2              3.0
# 2          403             324              109         3              3.5
# 3          404             330              116         4              4.0
# 4          405             311              101         3              2.0
# ..         ...             ...              ...       ...              ...
# 95         496             332              108         5              4.5
# 96         497             337              117         5              5.0
# 97         498             330              120         5              4.5
# 98         499             312              103         4              4.0
# 99         500             327              113         4              4.5
#
#     GD_score  CGPA  Internship
# 0        3.0  8.22           0
# ...

# %%
wget https://examly467-my.sharepoint.com/:x:/r/personal/arumugham_iamneo_ai/_layouts/15/Doc.aspx?sourcedoc=%7B9ECCD100-51A5-4F9A-B480-FF04624BB4AC%7D&file=submission.csv
# Out:
#   File "<ipython-input-1-783385eb8a28>", line 1
#     wget https://examly467-my.sharepoint.com/:x:/r/personal/arumugham_iamneo_ai/_layouts/15/Doc.aspx?sourcedoc=%7B9ECCD100-51A5-4F9A-B480-FF04624BB4AC%7D&file=submission.csv
#          ^
# SyntaxError: invalid syntax

# %%
# !wget -O test.csv https://examly467-my.sharepoint.com/:x:/r/personal/arumugham_iamneo_ai/_layouts/15/Doc.aspx?sourcedoc=%7B9ECCD100-51A5-4F9A-B480-FF04624BB4AC%7D&file=submission.csv

# %%
pip install streamlit;
# Out:
# ...
#      |████████████████████████████████| 7.0 MB 4.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 74 kB 3.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 727 kB 52.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 159 kB 63.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 20.7 MB 52.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.6 MB 51.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 63 kB 2.0 MB/s  eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
strealmit run dataapp.py
# Out:
#   File "<ipython-input-2-33648ff407b4>", line 1
#     strealmit run dataapp.py
#               ^
# SyntaxError: invalid syntax

# %%
streamlit run dataapp.py
# Out:
#   File "<ipython-input-3-ebe3b928404e>", line 1
#     streamlit run dataapp.py
#               ^
# SyntaxError: invalid syntax

# %%
pip install streamlit;
# Out:
# ...
#      |████████████████████████████████| 7.0 MB 4.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.6 MB 60.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 74 kB 3.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 727 kB 61.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 20.7 MB 46.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 159 kB 53.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 63 kB 1.9 MB/s  eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print("hello");
# Out:
# hello
